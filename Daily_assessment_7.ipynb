# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dirty_cafe_sales.csv")
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df.isin(['NaN', 'UNKNOWN', 'null']).sum()
# Out:
# Transaction ID        0
# Item                344
# Quantity            171
# Price Per Unit      164
# Total Spent         165
# Payment Method      293
# Location            338
# Transaction Date    159
# dtype: int64

# %%
df.replace(['UNKNOWN', 'ERROR', 'NaN', 'null', 'None'], np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 969
# Quantity             479
# Price Per Unit       533
# Total Spent          502
# Payment Method      3178
# Location            3961
# Transaction Date     460
# dtype: int64

# %%
missing_percent = (df.isna().sum() / len(df)) * 100
print(missing_percent)
# Out:
# Transaction ID       0.00
# Item                 9.69
# Quantity             4.79
# Price Per Unit       5.33
# Total Spent          5.02
# Payment Method      31.78
# Location            39.61
# Transaction Date     4.60
# dtype: float64

# %%
clean_percent = (df.notna().sum() / len(df)) * 100
print(clean_percent)
# Out:
# Transaction ID      100.00
# Item                 90.31
# Quantity             95.21
# Price Per Unit       94.67
# Total Spent          94.98
# Payment Method       68.22
# Location             60.39
# Transaction Date     95.40
# dtype: float64

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0         NaN
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df['Quantity'] = pd.to_numeric(df['Quantity'], errors='coerce')
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].median())

df['Price Per Unit'] = pd.to_numeric(df['Price Per Unit'], errors='coerce')
df['Price Per Unit'] = df['Price Per Unit'].fillna(df['Price Per Unit'].mean())

df['Total Spent'] = pd.to_numeric(df['Total Spent'], errors='coerce')
df['Total Spent'] = df['Total Spent'].fillna(df['Total Spent'].median())

# %%
df['Item'] = df['Item'].fillna(df['Item'].mode()[0])
df['Payment Method'] = df['Payment Method'].fillna(df['Payment Method'].mode()[0])
df['Location'] = df['Location'].fillna(df['Location'].mode()[0])

# %%
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'], errors='coerce')
df['Transaction Date'] = df['Transaction Date'].fillna(df['Transaction Date'].mode()[0])

# %%
print(df.isnull().sum())
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
df.head(10)
# Out:
#   Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373    Coffee       2.0             2.0          4.0
# 1    TXN_4977031      Cake       4.0             3.0         12.0
# 2    TXN_4271903    Cookie       4.0             1.0          8.0
# 3    TXN_7034554     Salad       2.0             5.0         10.0
# 4    TXN_3160411    Coffee       2.0             2.0          4.0
# 5    TXN_2602893  Smoothie       5.0             4.0         20.0
# 6    TXN_4433211     Juice       3.0             3.0          9.0
# 7    TXN_6699534  Sandwich       4.0             4.0         16.0
# 8    TXN_4717867     Juice       5.0             3.0         15.0
# 9    TXN_2064365  Sandwich       5.0             4.0         20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3  Digital Wallet  Takeaway       2023-04-27
# ...

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0        2.000000          4.0
# 1       TXN_4977031      Cake       4.0        3.000000         12.0
# 2       TXN_4271903    Cookie       4.0        1.000000          8.0
# 3       TXN_7034554     Salad       2.0        5.000000         10.0
# 4       TXN_3160411    Coffee       2.0        2.000000          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0        2.000000          4.0
# 9996    TXN_9659401     Juice       3.0        2.949984          3.0
# 9997    TXN_5255387    Coffee       4.0        2.000000          8.0
# 9998    TXN_7695629    Cookie       3.0        2.949984          3.0
# 9999    TXN_6170729  Sandwich       3.0        4.000000         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
df.describe()
# Out:
#            Quantity  Price Per Unit  Total Spent            Transaction Date
# count  10000.000000    10000.000000  10000.00000                       10000
# mean       3.027100        2.949984      8.87795  2023-06-25 05:52:13.440000
# min        1.000000        1.000000      1.00000         2023-01-01 00:00:00
# 25%        2.000000        2.000000      4.00000         2023-03-19 00:00:00
# 50%        3.000000        3.000000      8.00000         2023-06-24 00:00:00
# 75%        4.000000        4.000000     12.00000         2023-09-27 00:00:00
# max        5.000000        5.000000     25.00000         2023-12-31 00:00:00
# std        1.384614        1.243910      5.86059                         NaN
