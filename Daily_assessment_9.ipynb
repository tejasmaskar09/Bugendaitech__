# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("rain-agriculture.csv")
df.head(5)
# Out:
#        State Name  Year  Dist Code  State Code  RICE AREA (1000 ha)  \
# 0  andhra pradesh  1966       49.0         1.0           218.272727
# 1  andhra pradesh  1967       49.0         1.0           220.181818
# 2  andhra pradesh  1968       49.0         1.0           203.527273
# 3  andhra pradesh  1969       49.0         1.0           227.118182
# 4  andhra pradesh  1970       49.0         1.0           225.745455
#
#    RICE PRODUCTION (1000 tons)  RICE YIELD (Kg per ha)  WHEAT AREA (1000 ha)  \
# 0                   292.181818             1345.728182              0.227273
# 1                   302.090909             1337.355455              0.236364
# 2                   250.363636             1212.896364              0.327273
# 3                   280.509091             1268.754545              0.318182
# 4                   312.245455             1361.693636              0.245455
#
#    WHEAT PRODUCTION (1000 tons)  WHEAT YIELD (Kg per ha)  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# State Name             0
# Year                   0
# Dist Code              0
# State Code             0
# RICE AREA (1000 ha)    0
#                       ..
# YEAR                   0
# JUN                    0
# JUL                    0
# AUG                    0
# SEP                    0
# Length: 85, dtype: int64

# %%
df.describe()
# Out:
#               Year   Dist Code  State Code  RICE AREA (1000 ha)  \
# count   936.000000  936.000000  936.000000           936.000000
# mean   1991.500000  368.783840    9.768144           142.288064
# std      15.016355  313.408031    5.541112           118.121417
# min    1966.000000   25.000000    1.000000            -1.000000
# 25%    1978.750000  107.500000    5.000000            38.944643
# 50%    1991.500000  197.395963    9.500000            98.698913
# 75%    2004.250000  656.200000   15.000000           239.806818
# max    2017.000000  914.166667   19.000000           410.030667
#
#        RICE PRODUCTION (1000 tons)  RICE YIELD (Kg per ha)  \
# count                   936.000000              936.000000
# mean                    259.990342             1609.671215
# std                     253.117563              834.974147
# min                      -1.000000               -1.000000
# 25%                      58.951625              991.830545
# ...

# %%
df.shape
# Out:
# (936, 85)

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])


correlation_matrix = numeric_df.corr()

plt.figure(figsize=(18, 14))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="Year", y="RICE YIELD (Kg per ha)", hue="State Name", estimator="mean")
plt.title("Trend of RICE YIELD over the Years by State")
plt.ylabel("RICE YIELD (Kg per ha)")
plt.xlabel("Year")
plt.legend(title="State", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Average Monthly Rainfall (Monsoon Months)
plt.figure(figsize=(8, 6))
rain_cols = ['JUN', 'JUL', 'AUG', 'SEP']
rain_avg = df[rain_cols].mean()
sns.barplot(x=rain_avg.index, y=rain_avg.values, color="yellowgreen")  
plt.title("Average Monthly Rainfall (Monsoon Months)")
plt.ylabel("Rainfall (mm)")
plt.xlabel("Month")
plt.show()

# %%
rice_by_year = df.groupby("Year")["RICE PRODUCTION (1000 tons)"].sum()
plt.figure(figsize=(10, 6))
sns.barplot(x=rice_by_year.index, y=rice_by_year.values, color='skyblue')
plt.title("Rice Production by Year")
plt.xlabel("Year")
plt.ylabel("Rice Production (1000 tons)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_years = rice_by_year.sort_values(ascending=False).head(6)

plt.figure(figsize=(8, 8))
plt.pie(top_years.values, labels=top_years.index, autopct='%1.1f%%', startangle=90)
plt.title("Rice Production Share - Top 6 Years")
plt.axis('equal')  
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.stripplot(data=df, x="State Name", y="MAIZE YIELD (Kg per ha)", jitter=True)
plt.title("Maize Yield by State (Strip Plot)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))
sns.violinplot(data=df, x="State Name", y="RICE YIELD (Kg per ha)")
plt.title("Distribution of Rice Yield by State (Violin Plot)")
plt.xticks(rotation=90)
plt.savefig("my_plot1.png", dpi=300, bbox_inches='tight') 
plt.tight_layout()

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=df, x="State Name", y="WHEAT YIELD (Kg per ha)")
plt.title("Wheat Yield Distribution by State")
plt.xticks(rotation=90)
plt.savefig("my_plot.png", dpi=300, bbox_inches='tight') 

plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x="Year", y="RICE PRODUCTION (1000 tons)", hue="State Name", estimator="mean")
plt.title("Rice Production Trend Over Years")
plt.tight_layout()
plt.savefig("rice_production_trend.png", dpi=300)
plt.show()
